# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
path = "Resources/WFH_WFO_dataset.csv"
wfh_wfo_df = pd.read_csv(path)
wfh_wfo_df.head()
# Out:
#    ID      Name  Age Occupation  Gender Same_ofiice_home_location kids  \
# 0   1   Bhavana   45      Tutor  Female                       Yes  Yes
# 1   2     Harry   24      Tutor    Male                        No   No
# 2   3  Banditaa   53         HR  Female                       Yes  Yes
# 3   4    Neetha   26   Engineer  Female                       Yes   No
# 4   5       Ram   26  Recruiter    Male                       Yes   No
#
#   RM_save_money RM_quality_time RM_better_sleep calmer_stressed  \
# 0           Yes             Yes             Yes          CALMER
# 1            No              No              No          CALMER
# 2           Yes             Yes             Yes          CALMER
# 3           Yes             Yes              No        STRESSED
# 4            No             Yes              No        STRESSED
#
#    RM_professional_growth  RM_lazy  RM_productive digital_connect_sufficient  \
# ...

# %%
wfh_wfo_df = wfh_wfo_df.drop(["Name", "calmer_stressed", "digital_connect_sufficient"], axis = 1)
wfh_wfo_df.head()
# Out:
#    ID  Age Occupation  Gender Same_ofiice_home_location kids RM_save_money  \
# 0   1   45      Tutor  Female                       Yes  Yes           Yes
# 1   2   24      Tutor    Male                        No   No            No
# 2   3   53         HR  Female                       Yes  Yes           Yes
# 3   4   26   Engineer  Female                       Yes   No           Yes
# 4   5   26  Recruiter    Male                       Yes   No            No
#
#   RM_quality_time RM_better_sleep  RM_professional_growth  RM_lazy  \
# 0             Yes             Yes                       5        1
# 1              No              No                       2        2
# 2             Yes             Yes                       3        3
# 3             Yes              No                       3        4
# 4             Yes              No                       3        3
#
#    RM_productive  RM_better_work_life_balance  RM_improved_skillset  \
# ...

# %%
wfh_wfo_df = wfh_wfo_df.rename(columns = {"Same_ofiice_home_location": "remote"})

# %%
wfh_wfo_df.columns
# Out:
# Index(['ID', 'Age', 'Occupation', 'Gender', 'remote', 'kids', 'RM_save_money',
#        'RM_quality_time', 'RM_better_sleep', 'RM_professional_growth',
#        'RM_lazy', 'RM_productive', 'RM_better_work_life_balance',
#        'RM_improved_skillset', 'RM_job_opportunities', 'Target'],
#       dtype='object')

# %%
filepath = "Resources/2020_rws"
rws_2020_df = pd.read_csv(filepath, encoding = "utf-8")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_88524\610174157.py in <module>
#       1 filepath = "Resources/2020_rws"
# ----> 2 rws_2020_df = pd.read_csv(filepath, encoding = "utf-8")
#
# ...
